# %%
import pandas as pd
import nltk

from nltk.tokenize import word_tokenize
from nltk.tokenize import sent_tokenize
from nltk.tokenize import TweetTokenizer
from nltk.probability import FreqDist
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.sentiment.vader import SentimentIntensityAnalyzer

#this is sample data
from nltk.corpus import names  

from string import punctuation

# %%
location = "datasets/women_clothing_review.csv"
df = pd.read_csv(location)

# %%
df.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name
# 0                        0       Initmates        Intimate  Intimates
# ...

# %%
sid = SentimentIntensityAnalyzer()

# %%
eng_stopwords = stopwords.words('english')

# %%
len(df['Review Text'])
# Out:
# 23486

# %%
missing = df['Review Text'].isnull()
df.loc[missing]
# Out:
#        Unnamed: 0  Clothing ID  Age Title Review Text  Rating  \
# 92             92          861   23   NaN         NaN       5
# 93             93         1081   31   NaN         NaN       5
# 98             98         1133   50   NaN         NaN       5
# 135           135          861   35   NaN         NaN       4
# 142           142         1126   35   NaN         NaN       5
# 165           165          829   35   NaN         NaN       3
# 168           168          862   40   NaN         NaN       5
# 192           192          895   46   NaN         NaN       5
# 201           201          895   36   NaN         NaN       5
# 248           248         1030   28   NaN         NaN       5
# 265           265          878   63   NaN         NaN       4
# 298           298         1104   39   NaN         NaN       5
# 323           323          895   47   NaN         NaN       5
# 342           342          836   32   NaN         NaN       5
# ...

# %%
newdf = df.dropna(subset = ['Review Text'])
len(newdf)
# Out:
# 22641

# %%
def reviewSentiment(text): 
    
    text = str(text).lower()                       #lowercase
    tktn_text = word_tokenize(text)           #tokenize
    
    for t in tktn_text:                            #punctuation
        if t in punctuation: 
            tktn_text.remove(t)
    
    clean_text = []                           # remove stopwords
    for txt in tktn_text: 
        if txt not in eng_stopwords:
            clean_text.append(txt)
    
    clean_review = " ".join(clean_text)        # consolidate
    
    sid_rev = sid.polarity_scores(clean_review)    #sentiment score
    r_comp = sid_rev['compound']
    
    return r_comp

# %%
newdf['Review Sentiment Value'] = newdf['Review Text'].apply(reviewSentiment)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
newdf.head()
# Out:
#    Unnamed: 0  Clothing ID  Age                    Title  \
# 0           0          767   33                      NaN
# 1           1         1080   34                      NaN
# 2           2         1077   60  Some major design flaws
# 3           3         1049   50         My favorite buy!
# 4           4          847   47         Flattering shirt
#
#                                          Review Text  Rating  Recommended IND  \
# 0  Absolutely wonderful - silky and sexy and comf...       4                1
# 1  Love this dress!  it's sooo pretty.  i happene...       5                1
# 2  I had such high hopes for this dress and reall...       3                0
# 3  I love, love, love this jumpsuit. it's fun, fl...       5                1
# 4  This shirt is very flattering to all due to th...       5                1
#
#    Positive Feedback Count   Division Name Department Name Class Name  \
# 0                        0       Initmates        Intimate  Intimates
# ...
